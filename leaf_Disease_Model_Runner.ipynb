# %%
from tensorflow.keras.models import load_model

try:
    model = load_model("/Users/imeshaaluvihare/Desktop/Research/Identify Diseases for Lavender plant/mylavender_model.keras")
    print("Kavi their is a good news Model loaded successfully!")
except Exception as e:
    print("Kavi Their Is a bad news Failed to load the model.")
    print("Error:", e)
# Out:
# Kavi their is a good news Model loaded successfully!
